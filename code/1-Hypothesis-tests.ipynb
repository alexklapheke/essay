# %%
# Data-handling libraries
import pandas as pd
import numpy as np

# Statistical libraries
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# Graphing libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read in data

# %%
essays = {}
for i in range(1, 9):
    essays[i] = pd.read_csv(f"../data_private/essays_cleaned_set_{i}.csv")

# %%
essays[1].columns
# Out:
# Index(['essay_id', 'essay_set', 'essay', 'rater1_domain1', 'rater2_domain1',
#        'domain1_score', 'tokens', 'types', 'sent_len', 'word_len',
#        'semicolons', 'score'],
#       dtype='object')

# %%
cols = ["tokens", "types", "sent_len", "word_len", "semicolons", "score"]

# %%
for i in range(1, 9):
    sns.pairplot(essays[i][cols]);

# %%
plt.hist(essays[1]["types"] / essays[1]["tokens"])
# Out:
# (array([ 28., 436., 878., 363.,  49.,  16.,   7.,   3.,   2.,   1.]),
#  array([0.20683453, 0.28615108, 0.36546763, 0.44478417, 0.52410072,
#         0.60341727, 0.68273381, 0.76205036, 0.84136691, 0.92068345,
#         1.        ]),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(essays[1]["types"] / essays[1]["tokens"], essays[1]["score"]);

# %%
for col in X:
    plt.figure(figsize=(10, 10))
    plt.title(col)
    plt.scatter(essays[1][col], essays[1][y])
